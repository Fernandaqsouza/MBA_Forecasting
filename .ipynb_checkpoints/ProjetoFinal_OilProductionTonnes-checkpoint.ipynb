# %% [markdown]
# # Chuvas em Fortaleza
#
# Projeto final da disciplina **Forecasting**
#
# #### **Aluna:** Fernanda de Queiroz Souza
#
# *Fonte: https://github.com/Eraylson/series_temporais*

# %% [markdown]
# ## Bibliotecas

# %%
#!pip install pmdarima

# %%
import pandas as pd
import numpy as np

import statsmodels.api as sm
import statsmodels.tsa.api as tsa
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams

import os

import datetime
from datetime import datetime, date, time, timedelta

import statsmodels.api as sm
import statsmodels.tsa.api as tsa
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import adfuller, kpss

#import pmdarima as pm
#from pmdarima import auto_arima

import sklearn
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, make_scorer
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split, StratifiedKFold, RandomizedSearchCV

# %%
import  warnings 
warnings.simplefilter('ignore')

# %%
# Configurando tamanho das imagens
rcParams['figure.figsize'] = 15, 6

# %% [markdown]
# ## Leitura dos dados

# %%
original_path = os.getcwd()
original_path
# Out:
# 'C:\\Users\\Fernanda.Souza\\OneDrive - Unilever\\Documents\\Jupyter\\MBA\\MBA_Forecasting'

# %%
os.chdir('C:/Users/Fernanda.Souza/OneDrive - Unilever/Documents/Jupyter/MBA/MBA_Forecasting/ProjetoFinal')

# %%
df = pd.read_excel('chuva_fortaleza.xlsx')

# %% [markdown]
# ## Análise dos dados

# %%
df
# Out:
#                     Year  Milimitros
# 0                   1850         852
# 1                   1851        1806
# 2                   1852        1356
# 3                   1853        1233
# 4                   1854        1590
# ..                   ...         ...
# 125  1975-01-01 00:00:00        1778
# 126  1976-01-01 00:00:00        1417
# 127  1977-01-01 00:00:00        1941
# 128  1978-01-01 00:00:00        1752
# 129  1979-01-01 00:00:00         996
#
# [130 rows x 2 columns]

# %%
df['Year'].value_counts()
# Out:
# 1850                   1
# 1947-01-01 00:00:00    1
# 1945-01-01 00:00:00    1
# 1944-01-01 00:00:00    1
# 1943-01-01 00:00:00    1
#                       ..
# 1888                   1
# 1887                   1
# 1886                   1
# 1885                   1
# 1979-01-01 00:00:00    1
# Name: Year, Length: 130, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        130 non-null    object
#  1   Milimitros  130 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df['Year'] = df['Year'].astype(str)

# %%
df['Year'] = df['Year'].str[0:4]
df
# Out:
#      Year  Milimitros
# 0    1850         852
# 1    1851        1806
# 2    1852        1356
# 3    1853        1233
# 4    1854        1590
# ..    ...         ...
# 125  1975        1778
# 126  1976        1417
# 127  1977        1941
# 128  1978        1752
# 129  1979         996
#
# [130 rows x 2 columns]

# %%
df['Year'] = df['Year'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        130 non-null    int32
#  1   Milimitros  130 non-null    int64
# dtypes: int32(1), int64(1)
# memory usage: 1.6 KB

# %%
df = df.set_index('Year')

# %%
df
# Out:
#       Milimitros
# Year
# 1850         852
# 1851        1806
# 1852        1356
# 1853        1233
# 1854        1590
# ...          ...
# 1975        1778
# 1976        1417
# 1977        1941
# 1978        1752
# 1979         996
#
# [130 rows x 1 columns]

# %%
#df.set_index('Year',inplace=True)
#df.index=df.index.astype(int)

# %%
# Conferindo se realmente não tem nenhum dado faltante na série

print(f'Valores faltantes: {df.isnull().values.any()}!')
# Out:
# Valores faltantes: False!

# %% [markdown]
# ## Análise da série

# %%
plt.figure(figsize=(10,5))
plt.title('Chuvas em Fortaleza')
plt.xlabel("Tempo")
plt.ylabel("Milimitros")
plt.plot(df['Milimitros'])

# %%
df_decomp = tsa.seasonal_decompose(df['Milimitros'], period=12)
df_decomp.plot();

# %%
rolmean12 = df['Milimitros'].rolling(window = 12).mean()
rolstd12 = df['Milimitros'].rolling(window = 12).std()

plt.figure(figsize=(7, 5))
actual = plt.plot(df['Milimitros'], color='black', label='Time Series', alpha=0.7)
rm_12 = plt.plot(rolmean12, color='red', label='RM_12', linestyle='dotted')#, 'bo') 
std_12 = plt.plot(rolstd12, color='blue', label='STD_12', linestyle='dashed')#, fmt='2')
plt.legend(loc='best')
plt.xlabel("Time")
plt.ylabel("Target")
plt.show()

# %%
plot_acf(df['Milimitros'], lags=20)
plot_pacf(df['Milimitros'], lags=20)
plt.show()

# %%
def teste_df(serie):
    #H0: série não estacionária 
    dftest = adfuller(serie, autolag='AIC')
    df_output = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags','Nº Observações'])
    for key,value in dftest[4].items():
        df_output['Valor Crítico (%s)'%key] = value
    print(df_output)
    if df_output[0] < df_output['Valor Crítico (5%)']: # descarta a H0 se o teste estatistico for menor que o valor crítico 
        print('estacionária')
    else:
        print(df_output[0])
        print('não estacionária')

# %%
teste_df(df['Milimitros'].values)
# Out:
# Test Statistic        -8.705081e+00
# p-value                3.719028e-14
# #Lags                  0.000000e+00
# Nº Observações         1.290000e+02
# Valor Crítico (1%)    -3.482088e+00
# Valor Crítico (5%)    -2.884219e+00
# Valor Crítico (10%)   -2.578864e+00
# dtype: float64
# estacionária

# %% [markdown]
# ## Pré - processamento

# %% [markdown]
# Solicitação: Divida a série nos conjuntos de treinamento, validação e teste com as seguintes porcentagens:
# 50%, 25% e 25%, seguindo a ordem temporal. Desenvolva, avalie e compare os modelos no
# cenário da previsão de um passo à frente.

# %%
print('Quantidade de linhas a serem consideradas')
print('Total:',df.shape[0])
print('Train:',(df.shape[0])*0.5)
print('Validation:',(df.shape[0])*0.25)
print('Test:',(df.shape[0])*0.25)
# Out:
# Quantidade de linhas a serem consideradas
# Total: 130
# Train: 65.0
# Validation: 32.5
# Test: 32.5

# %%
train = df.loc[0:65]
validation = df.loc[66:98]
test = df.loc[99:]

# %% [markdown]
# ## Metodologia Box-Jenkins

# %% [markdown]
# ### (1) Identificação:

# %%
acf_pacf(train.Milimitros, 20)

# %% [markdown]
# #### Escolha do parâmetro (d):

# %%
arima_d = 0

# %% [markdown]
# #### Escolha do parâmetro (p):
#
# Avaliando FACP (Partial Autocorrelation)

# %%
arima_p = 1

# %% [markdown]
# #### Escolha do parâmetro (q):
#
# Avaliando FAC (Autocorrelation)

# %%
arima_q = 1

# %% [markdown]
# ### (2.1) Estimação:

# %%
model = ARIMA(train.Milimitros, order=(arima_p, arima_d, arima_q))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Milimitros   No. Observations:                   66
# Model:                 ARIMA(1, 0, 1)   Log Likelihood                -501.200
# Date:                Sat, 24 Sep 2022   AIC                           1010.399
# Time:                        15:49:21   BIC                           1019.158
# Sample:                             0   HQIC                          1013.860
#                                  - 66
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1403.1358     90.627     15.483      0.000    1225.511    1580.761
# ar.L1          0.4538      0.450      1.008      0.313      -0.428       1.336
# ma.L1         -0.2161      0.460     -0.469      0.639      -1.118       0.686
# sigma2      2.364e+05   4.36e+04      5.423      0.000    1.51e+05    3.22e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                 1.59
# Prob(Q):                              0.89   Prob(JB):                         0.45
# Heteroskedasticity (H):               2.62   Skew:                             0.37
# Prob(H) (two-sided):                  0.03   Kurtosis:                         3.13
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### (2.2) Avaliação/Diagnóstico:

# %%
model_fit.plot_diagnostics(figsize=(16,8));

# %% [markdown]
# ### (3) Previsão:

# %%
previsao = model_fit.predict(start=105, end=130)

obs_train = plt.plot(train.Milimitros, color='black', label='Obs (train)')
obs_test = plt.plot(test.Milimitros, color='blue', label= 'Obs (test)', linestyle='dotted')#, 'bo') 
pred = plt.plot(previsao, color='red', label='Previsão', linestyle='dotted')#, 'bo') 

plt.legend(loc='best')
plt.xlabel("Time")
plt.ylabel("MVF")
plt.show()
# previsao

# %%
pred = model_fit.predict(start=len(train), end=len(test+train)-1)
obs = test.Milimitros

pred_df = pd.DataFrame()
pred_df['pred'] = pred
pred_df['obs'] = obs

pred_df.plot()
pred_df
# Out:
#             pred   obs
# 105  1306.030255  1152
# 106  1374.079064   806
# 107  1385.550053  1225
# 108  1387.483718   504
# 109  1387.809676  1493
# 110  1387.864622  1011
# 111  1387.873885  1737
# 112  1387.875446  1258
# 113  1387.875709  2102
# 114  1387.875754  2428
# 115  1387.875761  1630
# 116  1387.875762  1288
# 117  1387.875763  1839
# 118  1387.875763  1385
# 119  1387.875763  1805
# 120  1387.875763  1192
# 121  1387.875763  2093
# 122  1387.875763  1299
# 123  1387.875763  2331
# 124  1387.875763  2512
# 125  1387.875763  1778
# 126  1387.875763  1417
# 127  1387.875763  1941
# 128  1387.875763  1752
# 129  1387.875763   996

# %% [markdown]
# ## LIXO

# %%
#adf = adfuller(df)
#print(f'p-valor: {round(adf[1],2)}')

# %%
#df.info()

# %%
#Definindo as variáveis preditoras (X) e a target (y). Ainda não está pegando o bairro.
#X = df.iloc[:,1]
#y = df.iloc[:,2]

# %%
#X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size = 0.2, random_state = 0)
#X_train.shape
#y_train.shape

# %% [markdown]
# ### Eliminação da Tendência por Diferenciação

# %%
df_1ordem = df.diff()
plt.plot(df_1ordem, label="Diff - 1ª Ordem")
plt.legend(loc='best')
plt.show()

# %%
# A 13a observação será a média das 11 anteriores
rolmean12 = df.diff().rolling(window = 12).mean()
rolstd12 = df.diff().rolling(window = 12).std()

plt.figure(figsize=(7, 5))
actual = plt.plot(df['Milimitros'].diff(), color='black', label='Time Series', alpha=0.7)
rm_12 = plt.plot(rolmean12, color='red', label='RM_12', linestyle='dotted')#, 'bo') 
std_12 = plt.plot(rolstd12, color='blue', label='STD_12', linestyle='dashed')#, fmt='2')
plt.legend(loc='best')
plt.xlabel("Time")
plt.ylabel("Target")
plt.show()

# %%
plot_acf(df_1ordem, lags=50)
plot_pacf(df_1ordem, lags=50)
plt.show()

# %%
df_decomp_1ordem = tsa.seasonal_decompose(df_1ordem, period=12)
df_decomp_1ordem.plot();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 df_decomp_1ordem = tsa.seasonal_decompose(df_1ordem, period=12)
#       2 df_decomp_1ordem.plot()
#
# File ~\Anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py:146, in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     143 nobs = len(x)
#     145 if not np.all(np.isfinite(x)):
# --> 146     raise ValueError("This function does not handle missing values")
#     147 if model.startswith("m"):
#     148     if np.any(x <= 0):
#
# ValueError: This function does not handle missing values

# %%
#df_logged = df["ncasos"].apply(lambda x : np.log(x))

#ax1 = plt.subplot()
#df_logged.plot(figsize=(12,4) ,color="tab:red", title="Log Transformed Values", ax=ax1);

# %%
df_logg = np.log(df)
plt.plot(df_logg, label = "Log - 1ª Ordem")
plt.legend(loc = 'best')
plt.show()

# %%
rolmean12 = np.log(df).rolling(window = 12).mean()
rolstd12 = np.log(df).rolling(window = 12).std()
plt.figure(figsize=(7, 5))
actual = plt.plot(np.log(df['ncasos']), color='black', label='Time Series', alpha=0.7)
rm_12 = plt.plot(rolmean12, color='red', label='RM_12', linestyle='dotted')#, 'bo') 
std_12 = plt.plot(rolstd12, color='blue', label='STD_12', linestyle='dashed')#, fmt='2')
plt.legend(loc='best')
plt.xlabel("Time")
plt.ylabel("Target")
plt.show()

# %%
plot_acf(df_logg.dropna(), lags=12, alpha=0.5);
plot_pacf(df_logg.dropna(), lags=12, alpha=0.5);

# %%
df_diff_logg = df_logg.diff()
plt.plot(df_diff_logg, label="Diff - Log - 1ª Ordem")
plt.legend(loc='best')
plt.show()

# %%
rolmean12 = df_diff_logg.rolling(window = 12).mean()
rolstd12 = df_diff_logg.rolling(window = 12).std()
plt.figure(figsize=(7, 5))
actual = plt.plot(np.log(df_diff_logg['ncasos']), color='black', label='Time Series', alpha=0.7)
rm_12 = plt.plot(rolmean12, color='red', label='RM_12', linestyle='dotted')#, 'bo') 
std_12 = plt.plot(rolstd12, color='blue', label='STD_12', linestyle='dashed')#, fmt='2')
plt.legend(loc='best')
plt.xlabel("Time")
plt.ylabel("Target")
plt.show()

# %%
#df_logg2 = np.log(df_logg)
#plt.plot(df_logg, label = "Log - 2ª Ordem")
#plt.legend(loc = 'best')
#plt.show()

# %%
#rolmean12 = np.log(df_logg).rolling(window = 12).mean()
#rolstd12 = np.log(df_logg).rolling(window = 12).std()
#plt.figure(figsize=(7, 5))
#actual = plt.plot(np.log(df_logg['ncasos']), color='black', label='Time Series', alpha=0.7)
#rm_12 = plt.plot(rolmean12, color='red', label='RM_12', linestyle='dotted')#, 'bo') 
#std_12 = plt.plot(rolstd12, color='blue', label='STD_12', linestyle='dashed')#, fmt='2')
#plt.legend(loc='best')
#plt.xlabel("Time")
#plt.ylabel("Target")
#plt.show()

# %%
plot_acf(df_diff_logg.dropna(), lags=12, alpha=0.5);
plot_pacf(df_diff_logg.dropna(), lags=12, alpha=0.5);
