# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importando CSV
df = pd.read_csv("/content/drive/My Drive/Forecasting/USD_BRL Dados Históricos.txt", decimal=',')

#Convertendo a coluna "Data" para o tipo "datetime"
df["Data"] = pd.to_datetime(df["Data"], format="%d.%m.%Y")

#Deixando apenas a coluna da última cotação
df.drop(["Abertura",	"Máxima",	"Mínima",	"Var%"], axis=1, inplace=True)

#Reordenando - ordem crescente de data
df = df.sort_values('Data',ignore_index=True)
df
# Out:
#            Data  Último
# 0    2010-01-01  1.7430
# 1    2010-01-04  1.7212
# 2    2010-01-05  1.7310
# 3    2010-01-06  1.7325
# 4    2010-01-07  1.7465
# ...         ...     ...
# 2507 2019-08-13  3.9660
# 2508 2019-08-14  4.0526
# 2509 2019-08-15  3.9910
# 2510 2019-08-16  4.0058
# 2511 2019-08-19  3.9953
#
# [2512 rows x 2 columns]

# %%
#dividindo conjuntos de treinamento, teste e validação
print("50% = " + str(2512 * 0.5))
print("25% = " + str(2512 * 0.25))

df_train = df.loc[0:1255]
df_test = df.loc[1256:1884]
df_valid = df.loc[1884:]
# Out:
# 50% = 1256.0
# 25% = 628.0

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.tsa.api as tsa
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from matplotlib.pylab import rcParams

# %%
plt.figure(figsize = (10,5))
plt.xlabel("time")
plt.ylabel("Última cotação")
plt.plot(df["Data"], df["Último"])

# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.tsa.api as tsa
import matplotlib.pyplot as plt

def acf_pacf(x, qtd_lag):
    fig = plt.figure(figsize=(16,10))
    ax1 = fig.add_subplot(221)
    fig = sm.graphics.tsa.plot_acf(x, lags=qtd_lag, ax=ax1)
    ax2 = fig.add_subplot(222)
    fig = sm.graphics.tsa.plot_pacf(x, lags=qtd_lag, ax=ax2)
    plt.show()

# %%
acf_pacf(df_train['Último'], 20)

# %%
acf_pacf(df_train['Último'].diff().diff().dropna(), 15)

# %%
arima_d = 1

# %%
arima_p = 3

# %%
arima_q = 4

# %%
from statsmodels.tsa.arima.model import ARIMA

model = ARIMA(df_train['Último'], order=(arima_p, arima_d, arima_q))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                 Último   No. Observations:                 1256
# Model:                 ARIMA(3, 1, 4)   Log Likelihood                3379.182
# Date:                Sun, 25 Sep 2022   AIC                          -6742.365
# Time:                        16:59:34   BIC                          -6701.286
# Sample:                             0   HQIC                         -6726.925
#                                - 1256
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2762      0.329      0.841      0.400      -0.368       0.920
# ar.L2         -0.5850      0.165     -3.551      0.000      -0.908      -0.262
# ar.L3          0.5389      0.291      1.849      0.064      -0.032       1.110
# ma.L1         -0.3302      0.329     -1.005      0.315      -0.974       0.314
# ma.L2          0.5626      0.150      3.738      0.000       0.268       0.858
# ma.L3         -0.5203      0.278     -1.871      0.061      -1.065       0.025
# ma.L4         -0.0332      0.029     -1.127      0.260      -0.091       0.025
# sigma2         0.0003    6.8e-06     39.421      0.000       0.000       0.000
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):               533.00
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.79   Skew:                             0.02
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
model_fit.plot_diagnostics(figsize=(16,8))

# %%
previsao = model_fit.predict(start=1256, end=1884)

obs_train = plt.plot(df_train['Último'], color='black', label='Obs (train)')
obs_test = plt.plot(df_test['Último'], color='blue', label= 'Obs (test)', linestyle='dotted')#, 'bo') 
pred = plt.plot(previsao, color='red', label='Previsão', linestyle='dotted')#, 'bo') 

plt.legend(loc='best')
plt.xlabel("Time")
plt.ylabel("MVF")
plt.show()

# %%
pred = model_fit.predict(start=1256, end=1884)
obs = df_test['Último']

pred_df = pd.DataFrame()
pred_df['pred'] = pred
pred_df['obs'] = obs

pred_df.plot()
pred_df
# Out:
#           pred     obs
# 1256  2.470488  2.5226
# 1257  2.468629  2.4613
# 1258  2.471178  2.4612
# 1259  2.472076  2.4036
# 1260  2.469831  2.4783
# ...        ...     ...
# 1880  2.470890  3.0918
# 1881  2.470890  3.0726
# 1882  2.470890  3.0884
# 1883  2.470890  3.0880
# 1884  2.470890  3.1395
#
# [629 rows x 2 columns]

# %%
    from statsmodels.tsa.arima_process import ArmaProcess
    ar1 = rp.array({1,0.8})
    ma1 = rp.array({1})
    AR_object1 = ArmaProcess (ar1, ma1)
    rs_ar1 = AR_objects.generate_sample (nsample=500)
    fig = plt.figure(figsiezs(16,6))
    ax = fig.add_subplot(111)
    ax.plot(rs_ar1)
    acf_pacf(train.target, 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b4ba0f51fc07> in <module>
#       1 from statsmodels.tsa.arima_process import ArmaProcess
# ----> 2 ar1 = rp.array({1,0.8})
#       3 ma1 = rp.array({1})
#       4 AR_object1 = ArmaProcess (ar1, ma1)
#       5 rs_ar1 = AR_objects.generate_sample (nsample=500)
#
# NameError: name 'rp' is not defined

# %%
acf_pacf(rs_ar1,50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-357abe40e761> in <module>
# ----> 1 acf_pacf(rs_ar1,50)
#
# NameError: name 'acf_pacf' is not defined

# %%
#Segunda questão
#pré processamento
def get_lags(series, lags):
    result = []
    if lags > 0:
        for lag in range(1, lags+1):
            result.append(series.shift(lag).rename({series.columns[0]: series.columns[0]+'-'+str(lag)}, axis=1))
        return pd.concat(result, axis=1, names=list(range(-1,-lags))).dropna()
    else:
        for lag in range(-1, lags-1,-1):
            result.append(series.shift(lag).rename({series.columns[0]: series.columns[0]+'+'+str(abs(lag))}, axis=1))
        return pd.concat(result, axis=1, names=list(range(+1,-lags))).dropna()

# %%
#df2 = df

# create datetime index passing the datetime series
datetime_index = pd.DatetimeIndex(df['Data'].values)

df2=df.set_index(datetime_index)

# we don't need the column anymore
df2.drop('Data',axis=1,inplace=True)

df2.head()
# Out:
#             Último
# 2010-01-01  1.7430
# 2010-01-04  1.7212
# 2010-01-05  1.7310
# 2010-01-06  1.7325
# 2010-01-07  1.7465

# %%
df2['Último'][0:7]
# Out:
# 2010-01-01    1.7430
# 2010-01-04    1.7212
# 2010-01-05    1.7310
# 2010-01-06    1.7325
# 2010-01-07    1.7465
# 2010-01-08    1.7262
# 2010-01-11    1.7360
# Name: Último, dtype: float64

# %%
sliding_windows_df = get_lags(df2, 5)
sliding_windows_df.head()
# Out:
#             Último-1  Último-2  Último-3  Último-4  Último-5
# 2010-01-08    1.7465    1.7325    1.7310    1.7212    1.7430
# 2010-01-11    1.7262    1.7465    1.7325    1.7310    1.7212
# 2010-01-12    1.7360    1.7262    1.7465    1.7325    1.7310
# 2010-01-13    1.7480    1.7360    1.7262    1.7465    1.7325
# 2010-01-14    1.7570    1.7480    1.7360    1.7262    1.7465

# %%
X = sliding_windows_df
y = df2.reindex(X.index)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.4)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
print(y_train[0:1])
X_train.head()
# Out:
# (1504, 5)
# (1504, 1)
# (1003, 5)
# (1003, 1)
#             Último
# 2010-01-08  1.7262
#             Último-1  Último-2  Último-3  Último-4  Último-5
# 2010-01-08    1.7465    1.7325    1.7310    1.7212    1.7430
# 2010-01-11    1.7262    1.7465    1.7325    1.7310    1.7212
# 2010-01-12    1.7360    1.7262    1.7465    1.7325    1.7310
# 2010-01-13    1.7480    1.7360    1.7262    1.7465    1.7325
# 2010-01-14    1.7570    1.7480    1.7360    1.7262    1.7465

# %%
1504+1003+5 == len(df2)
# Out:
# True

# %%
from sklearn.neighbors import KNeighborsRegressor

model_knn = KNeighborsRegressor(n_neighbors=5, weights='distance')
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(weights='distance')

# %%
model_knn.predict(X_test)[:10]
# Out:
# array([[3.83244535],
#        [3.83041001],
#        [3.878715  ],
#        [3.89912759],
#        [3.93492449],
#        [3.98924489],
#        [3.90057126],
#        [3.88466633],
#        [3.86671916],
#        [3.84648006]])

# %%
fig, ax = plt.subplots()
ax.plot(model_knn.predict(X_test).flatten(), label='pred')
ax.plot(y_test.reset_index(drop=True), label='true')
plt.legend()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
results = {}

print('MVF - KNN model Results:\n')
print(mean_squared_error(model_knn.predict(X_test), y_test))
print(mean_absolute_error(model_knn.predict(X_test), y_test))
results['KNN'] = {'mse': mean_squared_error(model_knn.predict(X_test), y_test),
                      'mae': mean_absolute_error(model_knn.predict(X_test), y_test)}
# Out:
# MVF - KNN model Results:
#
# 0.004465104495985786
# 0.05142742840883739

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

residuals = model_knn.predict(X_test)-y_test
residuals.rename(columns={"target": "Residuals"}, inplace=True)
residuals.plot(label="Residuals")
residuals.plot.kde()
plot_acf(residuals, lags=10);

from statsmodels.tsa.stattools import adfuller

adf = adfuller(residuals)
print(f'p-valor: {round(adf[1],2)}')
# Out:
# p-valor: 0.0

# %%
from sklearn.svm import SVR

# %%
model_svr = SVR(C=1.0, epsilon=0.2, kernel='linear')
model_svr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(epsilon=0.2, kernel='linear')

# %%
print('MVK - SVR model Results')
print(mean_squared_error(model_svr.predict(X_test), y_test))
print(mean_absolute_error(model_svr.predict(X_test), y_test))
results['SVR'] = {'mse': mean_squared_error(model_svr.predict(X_test), y_test),
                  'mae': mean_absolute_error(model_svr.predict(X_test), y_test)}
# Out:
# MVK - SVR model Results
# 0.0047475177830760525
# 0.05825492188460102

# %%
results
# Out:
# {'KNN': {'mse': 0.004465104495985786, 'mae': 0.05142742840883739},
#  'SVR': {'mse': 0.0047475177830760525, 'mae': 0.05825492188460102}}

# %%
fig, ax = plt.subplots()
ax.plot(model_svr.predict(X_test), label='pred')
ax.plot(y_test.reset_index(drop=True), label='true')
plt.title('MVF - SVR MODEL')
plt.legend()

# %%
#!pip install tensorflow

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Criando o modelo
model_mlp = Sequential()
model_mlp.add(Dense(16, input_shape=(5,), activation='relu'))
model_mlp.add(Dense(16, activation='relu'))
model_mlp.add(Dense(1, activation='linear'))

# Configurando e treiando o modelo
model_mlp.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_squared_error'])
model_mlp.fit(X_train, y_train, epochs=250, batch_size=1, verbose=False, validation_split=0.2)

# %%
pred_mlp = model_mlp.predict(X_test)

# %%
print('MVK - MLP model Results')
print(mean_squared_error(model_mlp.predict(X_test), y_test))
print(mean_absolute_error(model_mlp.predict(X_test), y_test))
results['MLP'] = {'mse': mean_squared_error(model_mlp.predict(X_test), y_test),
                  'mae': mean_absolute_error(model_mlp.predict(X_test), y_test)}
# Out:
# MVK - MLP model Results
# 0.002002445960974974
# 0.03492973626651174

# %%
fig, ax = plt.subplots()
ax.plot(model_mlp.predict(X_test), label='pred')
ax.plot(y_test.reset_index(drop=True), label='true')
plt.title('MVF - MLP MODEL')
plt.legend()

# %%
round(pd.DataFrame(results), 2)
# Out:
#       KNN   SVR   MLP
# mse  0.00  0.00  0.00
# mae  0.05  0.06  0.03
